# %%
## -*- coding: utf-8 -*-
"""
@author: carlos
"""
import csv

# La siguiente función ayuda al usuario a definir que reporte quiere 
# generar
def elegir_reporte():
    print("¿Qué reporte desea generar?")
    print("-----------------------------------------------")
    print("1) Rutas de importación y exportación")
    print("2) Medio de transporte utilizado")
    print("3) Valor total de importaciones y exportaciones")
    print("-----------------------------------------------")
    reporte = int(input("Indique con número: "))
    print("-----------------------------------------------")
    print("-----------------------------------------------")
    return reporte

reporte = elegir_reporte()

# Creamos con este pedazo de código una lista que contiene todas las rutas
rutas = set()
with open("synergy_logistics_database.csv","r") as archivo_madre:
    lector = csv.DictReader(archivo_madre)
    for linea in lector:
        if (linea["destination"],linea["origin"]) not in rutas:
            tupla_de_ruta = (linea["origin"],linea["destination"])
            rutas.add(tupla_de_ruta)
rutas = list(rutas)
rutas.sort()


# Definimos función que calcule el total de exportaciones o importaciones
# por año para cada ruta 
def demanda_anual(ano,tipo):
    resultado_final = []
    with open("synergy_logistics_database.csv","r") as archivo_madre:
        lector = csv.DictReader(archivo_madre)
        for linea in lector:
            if int(linea["year"]) == ano and linea["direction"] == tipo:
                for ruta in rutas:
                    if ruta == (linea["origin"],linea["destination"]) or ruta == (linea["destination"],linea["origin"]):
                        resultado_final.append((ruta,int(linea["total_value"])))
    resultado_final.sort(key=lambda x: x[0],reverse=True)
    suma_final = []
    suma = resultado_final[0][1]
    for j in range(len(resultado_final)-1):
        if resultado_final[j][0] == resultado_final[j+1][0]:
            suma += resultado_final[j+1][1]
        else:
            suma_final.append((resultado_final[j][0],suma))
            suma = resultado_final[j+1][1]
    if resultado_final[-2][0] == resultado_final[-1][0]:
        suma_final.append((resultado_final[-2][0],suma))
    else:
        suma_final.append((resultado_final[-1][0],resultado_final[-1][1]))
    suma_final.sort(key=lambda x: x[1],reverse=True)
    return suma_final
# suma_final contiene todas las exportaciones o importaciones por rutas
# del año indicado.


# Creamos con este pedazo de código una lista que contiene todos los
# diferentes medios de transporte
transportes = set()
with open("synergy_logistics_database.csv","r") as archivo_madre:
    lector = csv.DictReader(archivo_madre)
    for linea in lector:
        if linea["transport_mode"] not in transportes:
            valor_de_ruta = linea["transport_mode"]
            transportes.add(valor_de_ruta)
transportes = list(transportes)
transportes.sort()


# La siguiente función ayuda a calcular el total de exportaciones más 
# importaciones por año para cada medio de transporte
def total_medios(ano):
    resultado_final = []
    with open("synergy_logistics_database.csv","r") as archivo_madre:
        lector = csv.DictReader(archivo_madre)
        for linea in lector:
            if int(linea["year"]) == ano:
                for transporte in transportes:
                    if transporte == linea["transport_mode"]:
                        resultado_final.append((transporte,int(linea["total_value"])))
    resultado_final.sort(key=lambda x: x[0],reverse=True)
    suma_final = []
    suma = resultado_final[0][1]
    for j in range(len(resultado_final)-1):
        if resultado_final[j][0] == resultado_final[j+1][0]:
            suma += resultado_final[j+1][1]
        else:
            suma_final.append((resultado_final[j][0],suma))
            suma = resultado_final[j+1][1]
    if resultado_final[-2][0] == resultado_final[-1][0]:
        suma_final.append((resultado_final[-2][0],suma))
    else:
        suma_final.append((resultado_final[-1][0],resultado_final[-1][1]))
    suma_final.sort(key=lambda x: x[1],reverse=True)
    return suma_final
# suma_final contiene todas las exportaciones e importaciones por medio
# de transporte para el año indicado.


# Creamos con este pedazo de código una lista que contiene todos los
# diferentes países de exportación e importación
paises = set()
with open("synergy_logistics_database.csv","r") as archivo_madre:
    lector = csv.DictReader(archivo_madre)
    for linea in lector:
        if linea["origin"] not in paises:
            valor_de_pais = linea["origin"]
            paises.add(valor_de_pais)
        if linea["destination"] not in paises:
            valor_de_pais = linea["destination"]
            paises.add(valor_de_pais)
paises = list(paises)
paises.sort()


# Definimos función que calcule el total de importaciones y exportaciones
# para un año determinado.
def total_exp_imp(ano):
    suma_final = 0
    with open("synergy_logistics_database.csv","r") as archivo_madre:
        lector = csv.DictReader(archivo_madre)
        for linea in lector:
            if int(linea["year"]) == ano:
                suma_final += int(linea["total_value"])
    return suma_final


# Definimos funcion que calcule, para un año determinado, el porcentaje
# que contribuyó cada país al total de exportaciones e importaciones.
def contribucion(ano):
    expos_total = total_exp_imp(ano)
    resultado_final = []
    with open("synergy_logistics_database.csv","r") as archivo_madre:
        lector = csv.DictReader(archivo_madre)
        for linea in lector:
            if int(linea["year"]) == ano:
                for pais in paises:
                    if pais == linea["origin"] or pais == linea["destination"]:
                        resultado_final.append((pais,int(linea["total_value"])))
    resultado_final.sort(key=lambda x: x[0],reverse=True)
    suma_final = []
    suma = resultado_final[0][1]
    for j in range(len(resultado_final)-1):
        if resultado_final[j][0] == resultado_final[j+1][0]:
            suma += resultado_final[j+1][1]
        else:
            suma_final.append((resultado_final[j][0],suma*100/expos_total))
            suma = resultado_final[j+1][1]
    if resultado_final[-2][0] == resultado_final[-1][0]:
        suma_final.append((resultado_final[-2][0],suma*100/expos_total))
    else:
        suma_final.append((resultado_final[-1][0],resultado_final[-1][1]*100/expos_total))
    suma_final.sort(key=lambda x: x[1],reverse=True)
    return suma_final
# suma_final contiene todas las exportaciones o importaciones por rutas
# del año indicado.


# Este código genera e imprime en pantalla los reportes.
login = True
while login == True:
    if reporte == 1:
        print("RUTAS DE IMPORTACIÓN Y EXPORTACIÓN")
        print("-----------------------------------------------")
        for i in [2015,2016,2017,2018,2019,2020]:
            print("-----------------------------------------------")
            print("Las siguientes son las diez rutas más demandadas de exportación del ",i)
            print("-----------------------------------------------")
            expos = demanda_anual(i,"Exports")
            print("Ruta            Cantidad")
            for j in range(10):
                print(f"{expos[j][0][0]}-{expos[j][0][1]}     {expos[j][1]}")
        for i in [2015,2016,2017,2018,2019,2020]:
            print("-----------------------------------------------")
            print("Las siguientes son las diez rutas más demandadas de importación del ",i)
            print("-----------------------------------------------")
            imports = demanda_anual(i,"Imports")
            print("Ruta            Cantidad")
            for j in range(10):
                print(f"{imports[j][0][0]}-{imports[j][0][1]}     {imports[j][1]}")
    
    
    if reporte == 2:
        print("METODO DE TRANSPORTE UTILIZADO")
        print("-----------------------------------------------")
        for i in [2015,2016,2017,2018,2019,2020]:
            print("-----------------------------------------------")
            print("Medios de transporte por volumen de importación y exportación para el ",i)
            print("-----------------------------------------------")
            transpos = total_medios(i)
            print("Transporte      Exportación+Importación")
            for j in range(4):
                print(f"{transpos[j][0]}     {transpos[j][1]}")

    
    if reporte == 3:
        print("VALOR TOTAL DE IMPORTACIONES Y EXPORTACIONES")
        print("-----------------------------------------------")
        for i in [2015,2016,2017,2018,2019,2020]:
            print("-----------------------------------------------")
            print("Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año ",i)
            print("-----------------------------------------------")
            contribuciones = contribucion(i)
            print("País      Contribución (%)")
            lim = contribuciones[0][1]
            for w in range(len(contribuciones)):
                if lim < 80.0:
                    print(f"{contribuciones[w][0]}     {round(contribuciones[w][1],2)}")
                    lim += contribuciones[w+1][1]
        
    
    
    print("--------------------------------------------")
    print("¿Desea generar otro reporte? (si/no)")
    respuesta = input("Indique su respuesta: ")
    print("--------------------------------------------")
    if respuesta == "si":
        reporte = elegir_reporte()
    elif respuesta == "no":
        print("Programa cerrado exitosamente")
        login = False
# Out:
# ¿Qué reporte desea generar?
# -----------------------------------------------
# 1) Rutas de importación y exportación
# 2) Medio de transporte utilizado
# 3) Valor total de importaciones y exportaciones
# -----------------------------------------------
# Indique con número:  1
# -----------------------------------------------
# -----------------------------------------------
# RUTAS DE IMPORTACIÓN Y EXPORTACIÓN
# -----------------------------------------------
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2015
# -----------------------------------------------
# Ruta            Cantidad
# USA-Canada     2815000000
# Netherlands-Belgium     2318113000
# France-Germany     2057000000
# Japan-Brazil     1776000000
# Japan-USA     1437000000
# Japan-South Korea     1039000000
# China-Brazil     1017000000
# Germany-China     974000000
# Germany-South Korea     902000000
# China-USA     835000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2016
# -----------------------------------------------
# Ruta            Cantidad
# France-USA     2587000000
# Germany-China     2167000000
# Russia-Netherlands     1675000000
# Japan-South Korea     1602000000
# Germany-Italy     1601026000
# France-Spain     1455000000
# USA-Belgium     1005000000
# China-Spain     1003000000
# South Korea-USA     939000000
# Italy-Spain     871000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2017
# -----------------------------------------------
# Ruta            Cantidad
# Germany-Italy     4355051000
# Germany-China     3116000000
# Japan-South Korea     2250000000
# China-USA     1908000000
# Russia-Belorussia     1496000000
# USA-Belgium     1366000000
# France-United Kingdom     1252025000
# Russia-Germany     1112000000
# China-Spain     859000000
# USA-Mexico     848000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2018
# -----------------------------------------------
# Ruta            Cantidad
# China-South Korea     5570000000
# France-United Kingdom     3807000000
# USA-Mexico     3733000000
# Japan-China     2292000000
# Russia-Belorussia     1819000000
# France-Germany     1481035000
# Japan-South Korea     929000000
# South Korea-Vietnam     828000000
# Belgium-United Kingdom     804077000
# Russia-China     787000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2019
# -----------------------------------------------
# Ruta            Cantidad
# China-Mexico     6725000000
# France-Belgium     5160000000
# South Korea-Vietnam     2709000000
# USA-Brazil     2384000000
# Canada-Mexico     1555000000
# Russia-China     1523000000
# Japan-China     1322000000
# Russia-Turkey     1185000000
# USA-Argentina     1151000000
# Japan-Mexico     818000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de exportación del  2020
# -----------------------------------------------
# Ruta            Cantidad
# Canada-Mexico     6561000000
# China-Mexico     5018000000
# South Korea-Vietnam     2603000000
# USA-Argentina     2008000000
# China-USA     1742000000
# Japan-Brazil     1592000000
# USA-Singapore     1311000000
# China-Rusia     929000000
# Belgium-United Kingdom     815000000
# Netherlands-Belgium     706017000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2015
# -----------------------------------------------
# Ruta            Cantidad
# USA-Mexico     1702000000
# Singapore-Thailand     1064000000
# Malaysia-Thailand     778000000
# China-Thailand     759000000
# Germany-South Korea     738000000
# Germany-USA     666000000
# USA-Thailand     664000000
# Japan-USA     527000000
# Japan-Thailand     387000000
# France-Germany     286000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2016
# -----------------------------------------------
# Ruta            Cantidad
# Spain-Germany     1356000000
# Singapore-China     1068000000
# Germany-USA     954000000
# Australia-Japan     920000000
# Singapore-Thailand     837000000
# China-Thailand     791000000
# Malaysia-Thailand     535000000
# USA-Thailand     521000000
# Spain-Mexico     498000000
# Japan-China     330000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2017
# -----------------------------------------------
# Ruta            Cantidad
# Germany-Mexico     1744000000
# Japan-Mexico     1351000000
# South Korea-Mexico     1020000000
# Malaysia-Thailand     964000000
# China-Thailand     930000000
# France-Poland     718000000
# Italy-Poland     585000000
# Germany-Poland     473000000
# Japan-Thailand     312000000
# Japan-China     288000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2018
# -----------------------------------------------
# Ruta            Cantidad
# Japan-Mexico     3268000000
# China-United Arab Emirates     1284000000
# Japan-China     1000000000
# China-Mexico     689000000
# Italy-Mexico     680000000
# Spain-Mexico     450000000
# USA-Canada     399000000
# Japan-USA     381000000
# Germany-Mexico     319000000
# France-Poland     312000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2019
# -----------------------------------------------
# Ruta            Cantidad
# Japan-United Arab Emirates     1970000000
# South Korea-United Arab Emirates     1661000000
# Japan-China     1493000000
# China-United Arab Emirates     1170000000
# Germany-China     956000000
# Russia-India     851000000
# Singapore-Thailand     744000000
# India-USA     644000000
# Japan-Mexico     214000000
# Malaysia-Thailand     162000000
# -----------------------------------------------
# Las siguientes son las diez rutas más demandadas de importación del  2020
# -----------------------------------------------
# Ruta            Cantidad
# Singapore-Thailand     1372000000
# China-Thailand     1351000000
# Malaysia-Thailand     1043000000
# China-United Arab Emirates     903000000
# India-Germany     548000000
# Vietnam-United Arab Emirates     540000000
# Spain-Germany     491000000
# India-USA     489000000
# USA-Thailand     383000000
# China-USA     372000000
# --------------------------------------------
# ¿Desea generar otro reporte? (si/no)
# Indique su respuesta:  si
# --------------------------------------------
# ¿Qué reporte desea generar?
# -----------------------------------------------
# 1) Rutas de importación y exportación
# 2) Medio de transporte utilizado
# 3) Valor total de importaciones y exportaciones
# -----------------------------------------------
# Indique con número:  2
# -----------------------------------------------
# -----------------------------------------------
# METODO DE TRANSPORTE UTILIZADO
# -----------------------------------------------
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2015
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     11306827000
# Road     8231077000
# Air     7023000000
# Rail     4437488000
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2016
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     18500041000
# Rail     5479198000
# Road     4710088000
# Air     3459111000
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2017
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     14838463000
# Air     9065068000
# Rail     8483234000
# Road     2042000000
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2018
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     17542148000
# Rail     10632394000
# Road     6502062000
# Air     2457374000
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2019
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     18486953000
# Air     9037995000
# Road     8732171000
# Rail     4684366000
# -----------------------------------------------
# Medios de transporte por volumen de importación y exportación para el  2020
# -----------------------------------------------
# Transporte      Exportación+Importación
# Sea     19856190000
# Rail     9911363000
# Air     7219599000
# Road     3053088000
# --------------------------------------------
# ¿Desea generar otro reporte? (si/no)
# Indique su respuesta:  si
# --------------------------------------------
# ¿Qué reporte desea generar?
# -----------------------------------------------
# 1) Rutas de importación y exportación
# 2) Medio de transporte utilizado
# 3) Valor total de importaciones y exportaciones
# -----------------------------------------------
# Indique con número:  3
# -----------------------------------------------
# -----------------------------------------------
# VALOR TOTAL DE IMPORTACIONES Y EXPORTACIONES
# -----------------------------------------------
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2015
# -----------------------------------------------
# País      Contribución (%)
# USA     33.09
# Japan     22.28
# China     19.96
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2016
# -----------------------------------------------
# País      Contribución (%)
# Germany     25.2
# USA     22.51
# China     22.11
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2017
# -----------------------------------------------
# País      Contribución (%)
# Germany     32.97
# China     23.24
# Mexico     19.81
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2018
# -----------------------------------------------
# País      Contribución (%)
# China     35.09
# Mexico     27.94
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2019
# -----------------------------------------------
# País      Contribución (%)
# China     33.89
# Mexico     24.03
# France     15.33
# -----------------------------------------------
# Lista de países que contribuyeron con el 80% de todas las importaciones y exportaciones para el año  2020
# -----------------------------------------------
# País      Contribución (%)
# Mexico     32.8
# China     27.07
# USA     18.71
# --------------------------------------------
# ¿Desea generar otro reporte? (si/no)
# Indique su respuesta:  no
# --------------------------------------------
# Programa cerrado exitosamente
